# %% [markdown]
# **Day 3**

# %% [markdown]
# **Control Flow with if / else and Conditional**

# %%
'''
if condition:
    do this
else:
    do this 
'''
# Out:
# '\nif condition:\n    do this\nelse:\n    do this \n'

# %%
'''
water_level = 50
if water_level > 80:
    print("Drain Water")
else:
    print("Continue") 
    '''
# Out:
# '\nwater_level = 50\nif water_level > 80:\n    print("Drain Water")\nelse:\n    print("Continue") \n    '

# %% [markdown]
# ![day 3 flowchart.png](attachment:f6128692-8c03-4698-8408-b73b1723aa20.png)

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is your hight in cm? "))
if height> 120:
    print("You can ride the rollercoaster")
else:
    print("Sorry you have to grow taller before you can ride")
# Out:
# Welcome to the rollercoaster!
# What is your hight in cm?  120
# Sorry you have to grow taller before you can ride

# %%
'''
Greater Than	            >	Checks if the left value is larger than the right.
Less Than	                <	Checks if the left value is smaller than the right.
Greater Than or Equal to	>=	Checks if the left value is larger than or the same as the right.
Less Than or Equal to	    <=	Checks if the left value is smaller than or the same as the right.
Equal	                    ==	Checks if two values are identical.
Not Equal	                !=	Checks if two values are not identical.
'''
# Out:
# '\nGreater Than\t            >\tChecks if the left value is larger than the right.\nLess Than\t                <\tChecks if the left value is smaller than the right.\nGreater Than or Equal to\t>=\tChecks if the left value is larger than or the same as the right.\nLess Than or Equal to\t    <=\tChecks if the left value is smaller than or the same as the right.\nEqual\t                    ==\tChecks if two values are identical.\nNot Equal\t                !=\tChecks if two values are not identical.\n'

# %%
#Modulo operator 
#Modulo operator gives the remainder
a = 10 % 3
print(a)
# Out:
# 1

# %%
'''
Coding challenge
Write some code about what you have learn in the modulo operator and conditional check in Python to check if the number in the input area is 
even or odd. If it is odd, print out "Odd"; otherwise, print out "Even".
'''
number_to_check = int(input("What is the number you want to check"))
if number_to_check % 2 == 0:
    print("Even")
else:
    print ("Odd")
# Out:
# What is the number you want to check 120
# Even

# %% [markdown]
# **Nested if statements and elif statements**

# %%
'''
if condition:
    if another condition:
        do this
    else:
        do this 
else:
    do this 
'''
# Out:
# '\nif condition:\n    if another condition:\n        do this\n    else:\n        do this \nelse:\n    do this \n'

# %% [markdown]
# ![day 3_1 flowchart.png](attachment:9e759ae4-73e3-4b03-bad2-6eee29114a96.png)

# %% [markdown]
# **Coding Exercise 5: BMI Calculator with Interpretations**

# %%
'''
BMI Calculator with Interpretations
Add some if/elif/else statements to the BMI calculator so that it interprets the BMI values calculated.
If the bmi is under 18.5 (not including), print out "underweight"
If the bmi is between 18.5 (including) and 25 (not including), print out "normal weight"
If the bmi is 25 (including) or over, print out "overweight"
'''

weight = float(input("Please eneter you weight (kg): "))
height =  float(input("Please eneter you height (m): "))

bmi = round(weight / (height ** 2), 2)
print(f"\nYour BMI is: {bmi}")
# 🚨 Do not modify the values above
# Write your code below 👇
if bmi < 18.5:
    print("underweight")
elif bmi < 25:
    print("normal weight")
else:
    print("overweight")
# Out:
# Please eneter you weight (kg):  80
# Please eneter you height (m):  2
# Your BMI is: 20.0
# normal weight

# %% [markdown]
# **Multiple If Statements in Succession**

# %% [markdown]
# ![day 3_3_flowchart.png](attachment:e1766be0-093f-4d84-ab99-fb00e310b05b.png)

# %%
print("Welcome to the rollercoaster!")
height = int(input("What is your hight in cm? "))
if height> 120:
    print("You can ride the rollercoaster")
    age = int(input("Waht is your age"))
    if age <= 12:
        print("Child ticket is $5.")
        bill = 5
    elif bmi < 18:
        print("Your ticket is $7. ")
        bill = 7
    else:
        print("Your ticket is $12. ")
        bill = 12
    want_photo = input("Do you want to have a photo take? Type y for Yes and n for No")
    if want_photo == "y":
        bill += 3
    print(f"Your final bill is {bill} ")    
else:
    print("Sorry you have to grow taller before you can ride")
# Out:
# Welcome to the rollercoaster!
# What is your hight in cm?  120
# Sorry you have to grow taller before you can ride

# %% [markdown]
# **Pizza Order Practice**

# %%
'''
Write Pizza Delivery Program
Congratulations, you have got a job at Python Pizza! Your first job is to build an automatic Pizza order program.
Based on a user's order, work out their final bill. Use the input function to get a user preference and then add up the total for their order
and tell them how much they have to pay.
'''
print("Welcome to Python Pizza Deliveries!")
size = input("What size pizza do you want? S, M, or L: ")
add_pepperoni = input("Do you want pepperoni? Y or N ")
extra_cheese = input("Do you want extra cheese? Y or N ")
bill = 0
if size == "S":
    bill += 15
    if add_pepperoni == "Y":
        bill += 3
elif size == "M":
    bill += 20
    if add_pepperoni == "Y":
        bill += 3
else:
    bill += 25
    if add_pepperoni == "Y":
        bill += 3
if extra_cheese == "Y":
    bill += 1
print(f"Your final bill is: ${bill}.")
# Out:
# Welcome to Python Pizza Deliveries!
# What size pizza do you want? S, M, or L:  S
# Do you want pepperoni? Y or N  N
# Do you want extra cheese? Y or N  Y
# Your final bill is: $16.

# %% [markdown]
# **Logical Operators**

# %%
'''
AND	Returns True if both conditions it connects are true.
OR	Returns True if at least one of the conditions it connects is true.
NOT	Reverses the Boolean value (turns True to False, and False to True).
'''
a = 12
a > 10 or a < 10 # True if anyone condition satisfies
# Out:
# True

# %%
a > 10 and a < 10  # True only if both condition satisfies
# Out:
# False

# %%
not a < 10
# Out:
# True

# %%
'''
Quiz 4: Logical Operators Quiz
Question 1:
What will the following code evaluate to?
not 5 == 5
1. True
2. False    Answer

Question 2:
What will the following code evaluate to?
False or True or False
1. True     Answer
2. False    
3. Syntax error

Question 3:
What will the following code print?
a = 5
b = 7
if a >= b and a != b:
    print("A")
elif not a >= b and a != b:
    print("B")
else:
    print("C")
1. A
2. B    Answer
3. C 
'''
# Out:
# '\nQuiz 4: Logical Operators Quiz\nQuestion 1:\nWhat will the following code evaluate to?\nnot 5 == 5\n1. True\n2. False    Answer\n\nQuestion 2:\nWhat will the following code evaluate to?\nFalse or True or False\n1. True     Answer\n2. False    \n3. Syntax error\n\nQuestion 3:\nWhat will the following code print?\na = 5\nb = 7\nif a >= b and a != b:\n    print("A")\nelif not a >= b and a != b:\n    print("B")\nelse:\n    print("C")\n1. A\n2. B    Answer\n3. C \n'

# %% [markdown]
# **Day 3 Project: Treasure Island**

# %% [markdown]
# ![day_3_4_flowchart.png](attachment:256ce30c-a048-4f26-b77c-ba50801c13d2.png)

# %%
print('''
*******************************************************************************
       |                   |                  |                     |
_________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
       |                `"=._o`"=._      _`"=._                     |
_________|_____________________:=._o "=._."_.-="o__"=.________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
       |           |o`"=._` , "` `; .". ,  "- .  `   |
_________|___________| ;`-.o`"=._; ." ` '`."\` . "-; ;____________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/____/_______|o;._    "      `".o|o_.--"    ;o;____/______/____/____
/______/______/____/_________"=._o--._        ; |____/______/____/____/____/_
____/______/____/____/______/____/____/____/____/____/____/____/____/____/____
*******************************************************************************
''')

print("Welcome to Treasure Island.")
print("Your mission is to find the treasure.")
choice_1 = input('You\'re at a crossroad, where do you want to go? Type "left" or "right".\n').lower()

if choice_1 == "left":
    choice_2 = input('You\'ve come to a lake. There is an island in the middle of the lake. Type "wait" to wait for a boat. Type "swim" to swim across.\n').lower()
    if choice_2 == "wait":
        choice_3 = input("You arrive at the island unharmed. There is a house with 3 doors. One red, one yellow and one blue. Which colour do you choose?\n").lower()
        if choice_3 == "red":
            print("It's a room full of fire. Game Over.")
        elif choice_3 == "blue":
            print("You enter a room of beasts. Game Over.")
        elif choice_3 == "yellow":
            print("You found the treasure! You Win!")
        else:
            print("You chose a door that doesn't exist. Game Over.")    
    else:
         print("You get attacked by an angry trout. Game Over.")     
else:
    print("You fell into a hole. Game Over.")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\`'
# <>:1: SyntaxWarning: invalid escape sequence '\`'
# C:\Users\Shakir Ullah\AppData\Local\Temp\ipykernel_37768\2480245093.py:1: SyntaxWarning: invalid escape sequence '\`'
#   print('''
# *******************************************************************************
#        |                   |                  |                     |
# _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#        |                `"=._o`"=._      _`"=._                     |
# _________|_____________________:=._o "=._."_.-="o__"=.________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#        |           |o`"=._` , "` `; .". ,  "- .  `   |
# ...
