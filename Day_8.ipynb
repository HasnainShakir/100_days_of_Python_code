# %% [markdown]
# **Day_8**

# %% [markdown]
# **Functions with Inputs**

# %%
"""
Previously, we have seen that a function allow us to package code in to a name block which can be used repeatedly at a later point.
1. Pause 1: Review,
create a function called gree().
write three print statements inside the function.
call the greet function and run your code. 

def my_function():
  do this with
  Then do this
  Finally do this 
"""
def greet():
  print("Hello Angela")
  print("How do you do Jack Bauer?")
  print("Isn't the weather nice today?")
greet()
# Out:
# Hello Angela
# How do you do Jack Bauer?
# Isn't the weather nice today?

# %%
"""
A function that allows the input
def my_function(something):
  do this with something
  Then do this
  Finally do this 
"""
def greet_with_name(name):
  print(f"Hello {name}")
  print(f"How do you do {name}?")
greet_with_name("Shakir")
# Out:
# Hello Shakir
# How do you do Shakir?

# %% [markdown]
# **Coding Exercise 7: Life in Weeks**

# %%
"""Life in Weeks
I was reading this article by Tim Urban - Your Life in Weeks(Link is given next cell) and realised just how little time we actually have.
Create a function called life_in_weeks() using maths and f-Strings that tells us how many weeks we have left, if we live until 90 years old.
It will take your current age as the input and output a message with our time left in this format:
You have x weeks left.
Where x is replaced with the actual calculated number of weeks the input age has left until age 90.
**Warning** The function must be called life_in_weeks for the tests to pass. Also the output must have the same punctuation and spelling as the 
example. Including the full stop!
Example Input
56
Example Output
You have 1768 weeks left.
How to test your code and see your output?
Udemy coding exercises do not have a console, so you cannot use input(). You will need to call your function with hard-coded values like so:
def life_in_weeks(age):
  # your code here
# Call your function with hard coded values
life_in_weeks(12)
"""

def life_in_weeks(age):
    total_life_in_weeks = 90 * 52
    age_weeks = age * 52
    left_weeks = total_life_in_weeks - age_weeks
    print(f"You have {left_weeks} weeks left.")
life_in_weeks(56)
# Out:
# You have 1768 weeks left.

# %% [markdown]
# [Your Life in Weeks](https://waitbutwhy.com/2014/05/life-weeks.html)

# %% [markdown]
# **Positional vs. Keyword Arguments**

# %%
#Positional Argument
def greet_with(name, location):
    print(f"Hello {name}")
    print(f"What is it like {location}?")
greet_with("Shakir", "Verona")
# Out:
# Hello Shakir
# What is it like Verona?

# %%
#Keyword Argument
def greet_with(name, location):
    print(f"Hello {name}")
    print(f"What is it like {location}?")
greet_with(name = "Shakir", location = "Verona")
#using keyword argument are independent of postion
greet_with(location = "Verona", name = "Shakir")
# Out:
# Hello Shakir
# What is it like Verona?
# Hello Shakir
# What is it like Verona?

# %% [markdown]
# **Coding Exercise 8: Love Calculator**

# %%
"""
Love Calculator
💪 This is a difficult challenge! 💪 
You are going to write a function called calculate_love_score() that tests the compatibility between two names. To work out the love score between 
two people: 
1. Take both people's names and check for the number of times the letters in the word TRUE occur.  
2. Then check for the number of times the letters in the word LOVE occur.   
3. Then combine these numbers to make a 2-digit number and print it out. 
e.g.
name1 = "Angela Yu" name2 = "Jack Bauer"
T occurs 0 times 
R occurs 1 time 
U occurs 2 times 
E occurs 2 times 
Total = 5 
L occurs 1 time 
O occurs 0 times 
V occurs 0 times 
E occurs 2 times 
Total = 3 
Love Score = 53
Example Input 
calculate_love_score("Kanye West", "Kim Kardashian")
Example Output
42
How to test your code and see your output?
Udemy coding exercises do not have a console, so you cannot use the input() function. You will need to call your function with hard-coded values like so:

def calculate_love_score(name1, name2):
  # your code here 
# Call your function with hard coded values
calculate_love_score("Kanye West", "Kim Kardashian")
"""

def calculate_love_score(name1, name2):
    combined_names = (name1 + name2).lower()

    true_count = sum(combined_names.count(c) for c in "true")

    love_count = sum(combined_names.count(c) for c in "love")

    love_score = int(f"{true_count}{love_count}")
    
    print(love_score)  # just print the number
    return love_score

calculate_love_score("Kanye West", "Kim Kardashian")
# Out:
# 42
# 42

# %%
#Simple Function


#Function that allows for input
#'name' is the parameter.
#'Jack Bauer' is the argument.
def greet_with_name(name):
  print(f"Hello {name}")
  print(f"How do you do {name}?")
greet_with_name("Jack Bauer")

#Functions with more than 1 input
def greet_with(name, location):
  print(f"Hello {name}")
  print(f"What is it like in {location}?")

#Calling greet_with() with Positional Arguments
greet_with("Jack Bauer", "Nowhere")
#vs.
greet_with("Nowhere", "Jack Bauer")


#Calling greet_with() with Keyword Arguments
greet_with(location="London", name="Angela")
