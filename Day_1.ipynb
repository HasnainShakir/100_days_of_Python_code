# %% [markdown]
# **Day 1**

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# **String Concatenation**

# %%
print("Hello" + "world!")
# Out:
# Helloworld!

# %%
print("Hello" " " + "Shakir")

print("""1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
2. Knead the dough for 10 minutes.
3. Add 3g of Salt.
4. Leave to rise for 2 hours.
5. Bake at 200 degrees C for 30 minutes.""")
# Out:
# Hello Shakir
# 1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
# 2. Knead the dough for 10 minutes.
# 3. Add 3g of Salt.
# 4. Leave to rise for 2 hours.
# 5. Bake at 200 degrees C for 30 minutes.

# %% [markdown]
# **To print more than one line in Python**

# %%
print('''1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl. \n 2. Knead the dough for 10 minutes.
3. Add 3g of Salt.
4. Leave to rise for 2 hours.
5. Bake at 200 degrees C for 30 minutes.''')
# Out:
# 1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
#  2. Knead the dough for 10 minutes.
# 3. Add 3g of Salt.
# 4. Leave to rise for 2 hours.
# 5. Bake at 200 degrees C for 30 minutes.

# %% [markdown]
# A **syntax error** occurs when code violates the formal grammatical rules of the language (like forgetting a colon after an if statement or missing a parenthesis), whereas an **indentation error** is a specific type of **syntax error** in Python that results from incorrect whitespace (usually spaces or tabs) used to define a block of code.

# %% [markdown]
# **Coding Exercise 2: Debugging Practice**
# Look at the code in the code editor. There are errors on all 5 lines of code. Fix the code so that it runs without errors.
# Try to run the code and debug each line using the error messages and feedback.
#
# **Fix the code below** 👇

# %%
# Fix the code below 👇
print("Notes from Day 1")
print("The print statement is used to output strings")
print("Strings are strings of characters")
print("String Concatenation is done with the + sign")
print("New lines can be created with a \\ and the letter n")
# Out:
# Notes from Day 1
# The print statement is used to output strings
# Strings are strings of characters
# String Concatenation is done with the + sign
# New lines can be created with a \ and the letter n

# %% [markdown]
# **Python Input Function**

# %%
input("What is your name?")
# Out:
# What is your name? Shakir
# 'Shakir'

# %%
print("Hello " + input("What is your name?") + "!")
# Out:
# What is your name? Shakir
# Hello Shakir!

# %% [markdown]
# **Python Variables**

# %%
#Learn to store a value in a container for later use
name=input("What is your name?")
print(name)
# Out:
# What is your name? Shakir
# Shakir

# %%
# To get the length of the string, use len()
a = "My name is Shakir"
print(len(a))
# Out:
# 17

# %% [markdown]
# **Coding Exercise 3: Variables**
# We have 2 variables glass1 and glass2. glass1 contains milk and glass2 contains juice. Write 3 lines of code to switch the contents of the variables. You are not allowed to type the words "milk" or "juice". You are only allowed to use variables to solve this exercise.

# %%
#Given
glass1 = "milk"
glass2 = "juice"
#first create another variable glass3 and put the value of glass1(milk) in the third variable
glass3 = glass1
#now transfer juice from glass2 to glass1
glass1 = glass2
#now transfer milk from  glass3 to glass2
glass2 = glass3
#print to see the result
print(glass1 + glass2)
# Out:
# juicemilk

# %% [markdown]
# **Variable Naming**

# %%
#Name to make sense
#there should be space
#if name has more than a single word, connect them using underscore (_)

# %% [markdown]
# **Day 1 Project: Band Name Generator**
# Click Run to run the final project you will build.
# Welcome to the Band Name Generator.
# What's the name of the city you grew up in?
# ....
# What's your pet's name?
# Your band name could be .....

# %%
print("Welcome to the Band Name Generator.")
city_name = input("What's the name of the city you grew up in? \n")
pet_name = input("What's your pet's name? \n")
print("Your band name could be" + " " + city_name + " " + pet_name)
# Out:
# Welcome to the Band Name Generator.
# What's the name of the city you grew up in?
#  Milan
# What's your pet's name?
#  Dog
# Your band name could be Milan Dog
